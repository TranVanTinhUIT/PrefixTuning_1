# %%
# !python --version

# %%
# !sudo rm -r /content/{repo}

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
token = "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"
repo = "PrefixTuning_1"
gpt2_medium_path = "/content/drive/MyDrive/gtp2-medium-s3/64652c50e84ddabb9bad81a37ff82624ab70053f402f8d9a58c0e90fb8289fb6.8769029be4f66a5ae1055eefdd1d11621b901d510654266b8681719fff492d6e"
meteor_15_folder = "/content/drive/MyDrive/Installed/meteor-1.5/"

# %%
# %cd /content/
# !git config --global user.email "tinhtv1996@gmail.com"
# !git config --global user.name "tranvantinh"
# !git config --global init.defaultbranch "main"

# %%
# %cd /content/
# !git clone https://{token}@github.com/TranVanTinhUIT/{repo}.git

# %%
import shutil

# %%
# Copy file gpt2-medium-s3 từ drive đến folder '{settings.OUTPUT_PATH}/contrast_LM/transformers/examples/control/gpt2-medium-s3'
shutil.copy(gpt2_medium_path, "/content/{}/output/contrast_LM/transformers/examples/control/gpt2-medium-s3".format(repo))

# không cần run cũng oke

# %%
# %cd /content/PrefixTuning_1
# !git pull

# %%
#Install Python 3.8 kernel in Google Colaboratory
# !wget -O mini.sh https://repo.anaconda.com/miniconda/Miniconda3-py38_4.8.2-Linux-x86_64.sh
# !chmod +x mini.sh
# !bash ./mini.sh -b -f -p /usr/local

# %%
import sys
sys.path.append('/usr/local/lib/python3.8/site-package')

# %%
# !conda create -n myenv python=3.6 -y

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
# cd /content/PrefixTuning_1/transformers
# pip install -e .

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
#
# cd /content/PrefixTuning_1/transformers
# pip install torch
# pip install nltk
# pip install unidecode
# pip install natsort

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
# pip list

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
#
# cd /content/PrefixTuning_1/gpt2
# python train_e2e.py --optim_prefix yes --preseqlen 3 --epoch 1 --learning_rate 0.00005 --mode webnlg --bsz 5 --seed 101
# Out:
# Streaming output truncated to the last 5000 lines.
# ('manufacturer', 'successor')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Aston_Martin_V8 : manufacturer : Aston_Martin | Aston_Martin_V8 : successor : Aston_Martin_Virage <|endoftext|> Aston Martin V8 is the successor to Aston Martin V8 which was manufactured by Aston Martin. <|endoftext|>
#
# ['|', 'Aston_Martin_V8', ':', 'relatedMeanOfTransportation', ':', 'Aston_Martin_DBS', '|', 'Aston_Martin_V8', ':', 'successor', ':', 'Aston_Martin_Virage']
# ('relatedMeanOfTransportation', 'successor')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
# ...

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv

# cd /content/PrefixTuning_1/gpt2
# python run_language_modeling.py         --output_dir=webnlg_models/webnlgprefixtune_y_3_act_cat_b=5-e=1_d=0.0_u=no_lr=5e-05_w=0.0_s=101_r=n_m=512_o=1_o=1         --model_type=gpt2         --model_name_or_path=gpt2-medium         --tokenizer_name=gpt2-medium         --per_device_train_batch_size 5         --per_device_eval_batch_size 5         --save_steps 500000         --num_train_epochs 1         --do_train         --train_data_file=/content/PrefixTuning_1/data/webnlg_challenge_2017/train.json         --do_eval         --line_by_line         --save_total_limit 1         --overwrite_output_dir         --task_mode webnlg         --eval_data_file=/content/PrefixTuning_1/data/webnlg_challenge_2017/dev.json          --tuning_mode prefixtune --logging_dir webnlg_models/runs/webnlgprefixtune_y_3_act_cat_b=5-e=1_d=0.0_u=no_lr=5e-05_w=0.0_s=101_r=n_m=512_o=1_o=1         --train_embs no --optim_prefix yes --preseqlen 3 --prefix_mode activation --format_mode cat --gradient_accumulation_steps 1 --learning_rate 5e-05 --weight_decay 0.0 --seed 101 --disable_tqdm --mid_dim 512 --init_random no --use_dropout no --prefix_dropout 0.0 --objective_mode 1 --evaluate_during_training --eval_steps 5000  --cache_dir /content/PrefixTuning_1/output/contrast_LM/transformers/examples/control/gpt2-medium-s3

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
# pip install unidecode
# pip install natsort

# %%
# !cp /content/PrefixTuning_1/output/contrast_LM/transformers/examples/text-generation/webNLG_results2_1epoch/webnlgprefixtune_test_beam.txt /content/PrefixTuning_1/evaluation/webnlg-automatic-evaluation/submissions

# %%
import shutil
shutil.copytree(meteor_15_folder, "/content/PrefixTuning_1/evaluation/meteor-1.5/")

# %%
# %cd /content/PrefixTuning_1/evaluation
# !chmod +x multi-bleu.perl
# Out:
# /content/PrefixTuning_1/evaluation

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
# cd /content/PrefixTuning_1/evaluation
# chmod +x multi-bleu.perl
# chmod +x ../multi-bleu.perl
# chmod +x ./webnlg-automatic-evaluation/meteor_eval.sh
# chmod +x ./webnlg-automatic-evaluation/ter_eval.sh
# bash run_eval_on_webnlg.sh
# Out:
# chmod: cannot access '../multi-bleu.perl': No such file or directory
# ./../output/contrast_LM/transformers/examples/text-generation/webNLG_results2_1epoch/webnlgprefixtune_test_beam.txt
# test-beam
# Gold count 1862
# reduced (new) 891
# reduced (old) 971
# ...

# %%
# %cd /content/PrefixTuning_1
# !git status

# %%
# !pip install unidecode
# !pip install natsort

# %%
# %cd /content/PrefixTuning_1/webnlg-baseline
# !python webnlg_relexicalise.py -i /content/PrefixTuning_1/webnlg-baseline/data-directory /content/PrefixTuning_1/output/contrast_LM/transformers/examples/text-generation/webNLG_results2/webnlgprefixtune_y_3_act_cat_b=5-e=1_d=0.0_u=no_lr=5e-05_w=0.0_s=101_r=n_m=512_o=1_o=1_valid_beam

# %%
# Xóa file gpt2-medium-s3/... (1.5GB) trước khi push lên git
# !rm /content/{repo}/output/contrast_LM/transformers/examples/control/gpt2-medium-s3/64652c50e84ddabb9bad81a37ff82624ab70053f402f8d9a58c0e90fb8289fb6.8769029be4f66a5ae1055eefdd1d11621b901d510654266b8681719fff492d6e

# Xóa cài đặt /content/PrefixTuning_1/evaluation/meteor-1.5
# !rm -r /content/{repo}/evaluation/meteor-1.5

# %%
# !git config -l

# %%
# %cd /content/{repo}
# !git status -u

# %%
# !git rm --cached /content/PrefixTuning_1/output/contrast_LM/transformers/examples/control/gpt2-medium-s3/64652c50e84ddabb9bad81a37ff82624ab70053f402f8d9a58c0e90fb8289fb6.8769029be4f66a5ae1055eefdd1d11621b901d510654266b8681719fff492d6e

# %%
# !echo "/content/PrefixTuning_1/output/contrast_LM/transformers/examples/control/gpt2-medium-s3/64652c50e84ddabb9bad81a37ff82624ab70053f402f8d9a58c0e90fb8289fb6.8769029be4f66a5ae1055eefdd1d11621b901d510654266b8681719fff492d6e" >> .gitignore
# !git add .gitignore

# %%
# %cd /content/{repo}
# !git add .
# !git commit -m "delete transformer large file"

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/TranVanTinhUIT/PrefixTuning_1.git (fetch)
# origin	https://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@github.com/TranVanTinhUIT/PrefixTuning_1.git (push)

# %%
# !git push origin main

# %%
# !pip install nltk

# %%
from nltk.translate.bleu_score import sentence_bleu
reference = [['Abilene',',', 'Texas','is', 'served', 'by', 'the', 'Abilene', 'regional', 'airport'],
             ['Abilene', 'Regional', 'Airport', 'serves', 'the', 'city', 'of', 'Abilene', 'in', 'Texas']]
candidate = ['Abilene', 'Regional',  'Airport',  'serves',  'the',  'city',  'of',  'Abilene', ',',  'Texas']
score = sentence_bleu(reference, candidate)
print('score:',score)
# Out:
# score: 0.8891397050194614
